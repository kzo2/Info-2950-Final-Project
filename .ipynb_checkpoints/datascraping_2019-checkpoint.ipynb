# %%
pip install spotipy
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install spotipy
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np
from collections import Counter

# %env SPOTIPY_CLIENT_ID = 3543bc68b7a64fa4896cb0c1d2499e33
# %env SPOTIPY_CLIENT_SECRET = b711f5fe2e9a417c89247f7036c9c069

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())
# Out:
# env: SPOTIPY_CLIENT_ID=3543bc68b7a64fa4896cb0c1d2499e33
# env: SPOTIPY_CLIENT_SECRET=b711f5fe2e9a417c89247f7036c9c069

# %%
#prints number of playlists with corona_terms in title/description
#this is helpful bc it helps us see ahead of time how huge the dataset is

terms = ["2019"]
for term in terms:
    playlists = sp.search('q="{}"'.format(term), type='playlist')
    number_playlists = playlists['playlists']['total']
    print(number_playlists)
# Out:
# 6129

# %%
#function that creates a list with the playlist name, URI & total number of tracks
def extract_playlist(x,list_):
    for i in x['playlists']['items']:
        list_.append({"name" : i['name'], "total":i["tracks"]['total'], "uri":i["uri"]})

# %%
#create a list of playlists
list_of_playlists = []

for term in terms:
    
    #use index (i) which are multiples of 50 -- random sample bc of search limitation
    #spotify can only give you 2000 results at a time
    #random sample of 40 playlists
    for i in range(0,2000,50):
        
        try:
            #create variable init_data that has random sample of playlists with terms
            playlist_data = sp.search('q="{}"'.format(term), type='playlist', limit=50, offset=i)
                        #limit = 50, can only return up to 50 items, random sample of 50 songs
                        #type = playlist, only return playlists
                        #offset = i, the index of the first item to return
            
            extract_playlist(playlist_data,list_of_playlists)
            #above function appends init_data to list_of_playlists
        
        except:
            print("Error")

# %%
#dataset is length 2000 --> sample of 40 playlists, from each playlist, sample of 50 songs
len(list_of_playlists)
# Out:
# 2000

# %%
#creates dataframe with list of playlists, dropping duplicates & delete their index
#only need to drop duplicates if you use multiple terms, i.e. Coronavirus AND Quarantine
playlists2019 = pd.DataFrame(list_of_playlists).drop_duplicates().reset_index(drop=True)

# %%
#creates csv file from df
playlists2019.to_csv("playlists2019.csv")

# %%
#for a random sample of playlists, takes random sample of tracks, creates a list of tracks and their uris
tracks = []

#using each uri code listed in the playlist.csv
for uri in playlists2019['uri']:
        
        length = sp.playlist_tracks(uri)['total']
        #playlist_tracks(parameter) is playlist id, aka uri
        #length is the playlist length of each individual playlist
    
        for i in range(0,length, 50):
            #from 0 to playlist length, take every other 50th index
            
            playlist_data = sp.playlist_tracks(uri, limit=50, offset=i)
            #playlist_tracks get URI of tracks in playlists, input URI
            #playlist_data now has playlist track data
            #replacing old data
            
            try:
                for k in playlist_data['items']:
                    tracks.append(k['track']["uri"])
                    
            except:
                pass

# %%
len(tracks)
# Out:
# 265723

# %%
#dataframe with individual track uri and count
df = pd.DataFrame.from_dict(Counter(tracks), orient='index').reset_index().rename(columns={"index":"uri", 0:"count"})

# %%
df
# Out:
#                                          uri  count
# 0       spotify:track:3WogGiNpaOmYcPwqslBgZG      5
# 1       spotify:track:3DlTgKZMiNkPa96dbLlfYO      4
# 2       spotify:track:6OkdbK4Y1zHsDI4w5y5MY0      2
# 3       spotify:track:23Na3MCF9QaYja7W7mVMxy      6
# 4       spotify:track:10OmfJCAYVzChZMH2CKBMT      1
# 155499  spotify:track:3UtEmGRyDog60Tv4XccUj1      2
# 155500  spotify:track:7xF14ej1q96PuH8gQnrvVy      1
# 155501  spotify:track:6oGjQE3HFmu9XC0GYVGfdn      1
# 155502  spotify:track:07p7690kN4UuLnYDC3KSOU      1
# 155503  spotify:track:4iCJFCEMamseAL6kfuaSN8      1
# 155504  spotify:track:1RZv4qMqe4Cnd61GLdNBc0      1
# 155505  spotify:track:5TgOqvnvUNmd1kciGvjyXC      1
# 155506  spotify:track:5TdRUo465NcC36DomkwGcd      1
# 155507  spotify:track:1ieEVrsengDJwgL7BthPiG      1
# 155508  spotify:track:1KuqhEpT0rU4TsWOMpsq1l      1
# 155509  spotify:track:3df66exRGFPBizAWdBeyzc      1
#
# [155510 rows x 2 columns]

# %%
#useful stats to help us understand frequency of the popular tracks
#to know when we should cut off our data/if necessary
df[(df['count']>4) & (df['count']<2000)].describe()
# Out:
#              count
# count  7298.000000
# mean     10.551384
# std       9.816036
# min       5.000000
# 25%       6.000000
# 50%       7.000000
# 75%      12.000000
# max     183.000000

# %%
#creates a csv file of the unfiltered track data
df.to_csv("tracks_list_2019_unfiltered.csv")

# %%
sliced_df_2019 = df[df['count']>4]
len(sliced_df_2019)
# Out:
# 7298

# %%
#filters important variables, makes the dataframe usable
def filter_data(x):
    data = sp.track(x['uri'])
    #sets data variable for each track
    
    name = data['name']
    pop = data['popularity']
    date = data['album']['release_date']
    explic = data['explicit']
    
    features = sp.audio_features(x['uri'])
    #uses spotify function to access audio features
    
    return {**x, 
            "name" : name, 
            'release_date': date, 
            "popularity" : pop,
            'explicit' : explic, 
            **features[0]}

# %%
final_df_2019 = sliced_df_2019.apply(lambda x: filter_data(x), axis=1, result_type='expand')

# %%
final_df_2019
# Out:
#         acousticness                                       analysis_url  \
# 0           0.153000  https://api.spotify.com/v1/audio-analysis/3Wog...
# 3           0.354000  https://api.spotify.com/v1/audio-analysis/23Na...
# 5           0.853000  https://api.spotify.com/v1/audio-analysis/4tSf...
# 17          0.000095  https://api.spotify.com/v1/audio-analysis/2SqZ...
# 27          0.378000  https://api.spotify.com/v1/audio-analysis/3WgK...
# 28          0.301000  https://api.spotify.com/v1/audio-analysis/6JVn...
# 31          0.203000  https://api.spotify.com/v1/audio-analysis/1sQ0...
# 34          0.336000  https://api.spotify.com/v1/audio-analysis/3w5b...
# 36          0.192000  https://api.spotify.com/v1/audio-analysis/21AT...
# 38          0.423000  https://api.spotify.com/v1/audio-analysis/3iT4...
# 41          0.504000  https://api.spotify.com/v1/audio-analysis/0scz...
# 50          0.200000  https://api.spotify.com/v1/audio-analysis/6Khu...
# 52          0.616000  https://api.spotify.com/v1/audio-analysis/10pC...
# 55          0.027400  https://api.spotify.com/v1/audio-analysis/5tol...
# 57          0.015300  https://api.spotify.com/v1/audio-analysis/2zuT...
# 69          0.124000  https://api.spotify.com/v1/audio-analysis/6hig...
# 84          0.050400  https://api.spotify.com/v1/audio-analysis/2Fit...
# 190         0.043300  https://api.spotify.com/v1/audio-analysis/0LiS...
# 198         0.118000  https://api.spotify.com/v1/audio-analysis/5DL6...
# 260         0.388000  https://api.spotify.com/v1/audio-analysis/1LO9...
# 262         0.519000  https://api.spotify.com/v1/audio-analysis/5roC...
# 269         0.278000  https://api.spotify.com/v1/audio-analysis/1l77...
# 270         0.169000  https://api.spotify.com/v1/audio-analysis/63bm...
# 276         0.218000  https://api.spotify.com/v1/audio-analysis/0LDn...
# 277         0.386000  https://api.spotify.com/v1/audio-analysis/7dOk...
# 278         0.005460  https://api.spotify.com/v1/audio-analysis/6VQy...
# 279         0.050500  https://api.spotify.com/v1/audio-analysis/5QK3...
# 280         0.007160  https://api.spotify.com/v1/audio-analysis/0SAQ...
# 281         0.157000  https://api.spotify.com/v1/audio-analysis/6YUB...
# 282         0.039300  https://api.spotify.com/v1/audio-analysis/3fZI...
# ...              ...                                                ...
# 113905      0.032300  https://api.spotify.com/v1/audio-analysis/2Ezn...
# 114120      0.212000  https://api.spotify.com/v1/audio-analysis/4Mqf...
# 115291      0.043100  https://api.spotify.com/v1/audio-analysis/0LfM...
# 116335      0.912000  https://api.spotify.com/v1/audio-analysis/3hwQ...
# 116336      0.965000  https://api.spotify.com/v1/audio-analysis/5tyM...
# 116424      0.918000  https://api.spotify.com/v1/audio-analysis/1LdS...
# 116792      0.002830  https://api.spotify.com/v1/audio-analysis/4D5u...
# 118083      0.060700  https://api.spotify.com/v1/audio-analysis/3u5G...
# 118684      0.747000  https://api.spotify.com/v1/audio-analysis/3s71...
# 120610      0.078800  https://api.spotify.com/v1/audio-analysis/2j5h...
# 121773      0.026700  https://api.spotify.com/v1/audio-analysis/4BLE...
# 124390      0.031000  https://api.spotify.com/v1/audio-analysis/62bO...
# 125377      0.523000  https://api.spotify.com/v1/audio-analysis/0fAB...
# 125535      0.406000  https://api.spotify.com/v1/audio-analysis/6iW5...
# 126274      0.844000  https://api.spotify.com/v1/audio-analysis/1nal...
# 126285      0.432000  https://api.spotify.com/v1/audio-analysis/0t4k...
# 127989      0.004820  https://api.spotify.com/v1/audio-analysis/7aJZ...
# 129006      0.093000  https://api.spotify.com/v1/audio-analysis/40Zb...
# 130620      0.731000  https://api.spotify.com/v1/audio-analysis/3Skt...
# 134179      0.249000  https://api.spotify.com/v1/audio-analysis/7obd...
# 137821      0.006320  https://api.spotify.com/v1/audio-analysis/2NjO...
# 139356      0.075300  https://api.spotify.com/v1/audio-analysis/2paS...
# 139366      0.247000  https://api.spotify.com/v1/audio-analysis/534R...
# 139370      0.393000  https://api.spotify.com/v1/audio-analysis/5JFO...
# 139371      0.532000  https://api.spotify.com/v1/audio-analysis/28gO...
# 139374      0.110000  https://api.spotify.com/v1/audio-analysis/5YFu...
# 139377      0.520000  https://api.spotify.com/v1/audio-analysis/6dYK...
# 139386      0.302000  https://api.spotify.com/v1/audio-analysis/0NGS...
# 139393      0.727000  https://api.spotify.com/v1/audio-analysis/1tnd...
# 139395      0.244000  https://api.spotify.com/v1/audio-analysis/321C...
#
#         count  danceability  duration_ms  energy  explicit  \
#
#         release_date speechiness    tempo time_signature  \
# 0         2019-10-04      0.0345  102.025              4
# 3         2004-11-23      0.0399  129.892              4
# 5         1996-10-01      0.0651   92.857              4
# 17        1990-08-01      0.0635  122.051              4
# 27              2003      0.1040   98.861              4
# 28              1994      0.0317  113.381              3
# 31        2009-05-05      0.0253   78.219              4
# 34        1998-07-01      0.1150   78.695              4
# 36        1999-12-31      0.0369   96.933              4
# 38        2015-02-02      0.0683   97.028              4
# 41        2005-11-16      0.0424  170.112              4
# 50        2014-01-28      0.0753  151.956              4
# 52        1974-01-01      0.0322  129.253              4
# 55        1999-10-12      0.0637  183.100              3
# 57        2004-03-31      0.0281  123.987              3
# 69        2005-05-03      0.0275  121.897              4
# 84        2005-05-03      0.0331   92.884              4
# 190       2020-01-17      0.0345  124.853              4
# 198       2019-10-03      0.0325  101.690              4
# 260       2018-09-07      0.0374  163.200              4
# 262       2018-08-02      0.0366  139.867              3
# 269       2017-04-21      0.0365  123.950              4
# 270       2017-08-25      0.0367  177.732              4
# 276       2019-10-25      0.0633  149.906              4
# 277       2019-10-01      0.0339  150.012              4
# 278       2019-08-29      0.0414  150.090              4
# 279       2019-10-04      0.0535  112.365              3
# 280       2019-08-14      0.2000  150.044              4
# 281       2018-08-13      0.0434  150.119              4
# 282       2019-07-09      0.0748   75.467              4
# ...              ...         ...      ...            ...
# 113905    2018-04-27      0.0590  134.799              4
# 114120    2019-05-31      0.3400  155.069              4
# 115291    2019-11-15      0.0392   64.822              4
# 116335    2019-08-30      0.0304   78.815              4
# 116336    2019-08-30      0.0392  134.238              4
# 116424    2020-02-07      0.0410  105.034              4
# 116792    2018-09-10      0.0732  127.971              4
# 118083    2018-08-01      0.0702  100.015              4
# 118684    2019-02-19      0.0360   87.016              4
# 120610    2018-06-15      0.0611  110.001              4
# 121773    2018-08-25      0.0350  127.966              4
# 124390    2000-03-21      0.0479  172.638              4
# 125377    2018-10-26      0.3140   78.458              4
# 125535    2019-08-30      0.0871  117.501              4
# 126274    2019-11-15      0.2490   74.741              4
# 126285    2019-11-07      0.0486  132.034              4
# 127989          1969      0.0347  120.082              4
# 129006    2019-04-16      0.2600   96.004              4
# 130620    2006-09-11      0.0342  123.980              3
# 134179    1996-04-29      0.0527  103.201              4
# 137821    2018-08-31      0.0470  117.016              4
# 139356    2019-03-15      0.0419  146.036              4
# 139366    2019-01-04      0.0405  145.040              4
# 139370    2018-05-18      0.1060   92.930              4
# 139371    2017-01-15      0.0431  100.054              4
# 139374    2017-10-06      0.0358  102.935              4
# 139377    2017-01-15      0.0493  122.980              4
# 139386    2017-01-15      0.0560   88.473              4
# 139393    2017-01-15      0.0404   80.110              4
# 139395    2017-01-15      0.0301   81.054              4
#
#                                                track_href            type  \
# 0       https://api.spotify.com/v1/tracks/3WogGiNpaOmY...  audio_features
# 3       https://api.spotify.com/v1/tracks/23Na3MCF9QaY...  audio_features
# 5       https://api.spotify.com/v1/tracks/4tSffeciMCcN...  audio_features
# 17      https://api.spotify.com/v1/tracks/2SqZ6pmqXB5s...  audio_features
# 27      https://api.spotify.com/v1/tracks/3WgK1nC3pQmJ...  audio_features
# 28      https://api.spotify.com/v1/tracks/6JVngSxUtrYk...  audio_features
# 31      https://api.spotify.com/v1/tracks/1sQ0oafDSZQU...  audio_features
# 34      https://api.spotify.com/v1/tracks/3w5bSQlQzKFU...  audio_features
# 36      https://api.spotify.com/v1/tracks/21ATIZAwB9QX...  audio_features
# 38      https://api.spotify.com/v1/tracks/3iT4c9MPnaor...  audio_features
# 41      https://api.spotify.com/v1/tracks/0sczR0OFWOGd...  audio_features
# 50      https://api.spotify.com/v1/tracks/6Khu8ivxbVt8...  audio_features
# 52      https://api.spotify.com/v1/tracks/10pCXoG0FfFq...  audio_features
# 55      https://api.spotify.com/v1/tracks/5tolMesLH4lI...  audio_features
# 57      https://api.spotify.com/v1/tracks/2zuTXMKi4tDh...  audio_features
# 69      https://api.spotify.com/v1/tracks/6higbPkv82W1...  audio_features
# 84      https://api.spotify.com/v1/tracks/2Fit4zvhoTT4...  audio_features
# 190     https://api.spotify.com/v1/tracks/0LiSASDl1Os4...  audio_features
# 198     https://api.spotify.com/v1/tracks/5DL6BDuqhnQw...  audio_features
# 260     https://api.spotify.com/v1/tracks/1LO951RWD10l...  audio_features
# 262     https://api.spotify.com/v1/tracks/5roCNZmSZyDw...  audio_features
# 269     https://api.spotify.com/v1/tracks/1l77YWrGUp3q...  audio_features
# 270     https://api.spotify.com/v1/tracks/63bmZnBN1CiJ...  audio_features
# 276     https://api.spotify.com/v1/tracks/0LDnOpACa7Yb...  audio_features
# 277     https://api.spotify.com/v1/tracks/7dOk9Bck00Zv...  audio_features
# 278     https://api.spotify.com/v1/tracks/6VQye74oX8FY...  audio_features
# 279     https://api.spotify.com/v1/tracks/5QK32vB1hmlE...  audio_features
# 280     https://api.spotify.com/v1/tracks/0SAQ2oSNEzGU...  audio_features
# 281     https://api.spotify.com/v1/tracks/6YUB4Wv4yJlu...  audio_features
# 282     https://api.spotify.com/v1/tracks/3fZIBSibgTdC...  audio_features
# ...                                                   ...             ...
# 113905  https://api.spotify.com/v1/tracks/2EznBGrlmx9w...  audio_features
# 114120  https://api.spotify.com/v1/tracks/4Mqfhqtb5Wmo...  audio_features
# 115291  https://api.spotify.com/v1/tracks/0LfMuWu6FKNS...  audio_features
# 116335  https://api.spotify.com/v1/tracks/3hwQhakFwm9s...  audio_features
# 116336  https://api.spotify.com/v1/tracks/5tyMJlMqaggz...  audio_features
# 116424  https://api.spotify.com/v1/tracks/1LdS1ULS9e18...  audio_features
# 116792  https://api.spotify.com/v1/tracks/4D5uw4lzpyBI...  audio_features
# 118083  https://api.spotify.com/v1/tracks/3u5GmyJP2MU3...  audio_features
# 118684  https://api.spotify.com/v1/tracks/3s71tbgmSN9T...  audio_features
# 120610  https://api.spotify.com/v1/tracks/2j5hsQvApott...  audio_features
# 121773  https://api.spotify.com/v1/tracks/4BLEnHP1FInl...  audio_features
# 124390  https://api.spotify.com/v1/tracks/62bOmKYxYg7d...  audio_features
# 125377  https://api.spotify.com/v1/tracks/0fABHG5a7Rnq...  audio_features
# 125535  https://api.spotify.com/v1/tracks/6iW5pbOAevzr...  audio_features
# 126274  https://api.spotify.com/v1/tracks/1nal3Tf1OCV5...  audio_features
# 126285  https://api.spotify.com/v1/tracks/0t4knmBuw14L...  audio_features
# 127989  https://api.spotify.com/v1/tracks/7aJZxI6TVdIv...  audio_features
# 129006  https://api.spotify.com/v1/tracks/40Zb4FZ6nS1H...  audio_features
# 130620  https://api.spotify.com/v1/tracks/3SktMqZmo3M9...  audio_features
# 134179  https://api.spotify.com/v1/tracks/7obdw7ZGr6l1...  audio_features
# 137821  https://api.spotify.com/v1/tracks/2NjO87HyT80f...  audio_features
# 139356  https://api.spotify.com/v1/tracks/2paS5IrhWd23...  audio_features
# 139366  https://api.spotify.com/v1/tracks/534RPnwnHbkv...  audio_features
# 139370  https://api.spotify.com/v1/tracks/5JFOYTBWdEgS...  audio_features
# 139371  https://api.spotify.com/v1/tracks/28gOXjOxJz2t...  audio_features
# 139374  https://api.spotify.com/v1/tracks/5YFuOQ9AI7WD...  audio_features
# 139377  https://api.spotify.com/v1/tracks/6dYKKXUjHiOJ...  audio_features
# 139386  https://api.spotify.com/v1/tracks/0NGSPHHIeaKZ...  audio_features
# 139393  https://api.spotify.com/v1/tracks/1tndIFaPXaZK...  audio_features
# 139395  https://api.spotify.com/v1/tracks/321CNgvw2N4m...  audio_features
#
#                                          uri valence
# 0       spotify:track:3WogGiNpaOmYcPwqslBgZG  0.6390
# 3       spotify:track:23Na3MCF9QaYja7W7mVMxy  0.5300
# 5       spotify:track:4tSffeciMCcNIvITmh6QHP  0.6270
# 17      spotify:track:2SqZ6pmqXB5szlwEgaeDYW  0.6000
# 27      spotify:track:3WgK1nC3pQmJ9UtBF4oNMR  0.8730
# 28      spotify:track:6JVngSxUtrYkWfFmFWmtm5  0.2390
# 31      spotify:track:1sQ0oafDSZQUElkV5ERvLx  0.4350
# 34      spotify:track:3w5bSQlQzKFUE3osgrMRBT  0.6480
# 36      spotify:track:21ATIZAwB9QXBOpTzw2lDM  0.5090
# 38      spotify:track:3iT4c9MPnaordWrfvTs8MU  0.8700
# 41      spotify:track:0sczR0OFWOGd9U8tECZ47Z  0.9620
# 50      spotify:track:6Khu8ivxbVt8xHJVfVliLU  0.5830
# 52      spotify:track:10pCXoG0FfFqk2ltikjuEf  0.4890
# 55      spotify:track:5tolMesLH4lIK2dTrCHmXO  0.2950
# 57      spotify:track:2zuTXMKi4tDhy7ZYHbQpli  0.0888
# 69      spotify:track:6higbPkv82W1ZwCeZIVGv3  0.5900
# 84      spotify:track:2Fit4zvhoTT4KLQj1T7HHQ  0.7910
# 190     spotify:track:0LiSASDl1Os4c8JeiypsT8  0.8230
# 198     spotify:track:5DL6BDuqhnQw8HfIvUYkm9  0.5340
# 260     spotify:track:1LO951RWD10l9Vys0NrFty  0.6320
# 262     spotify:track:5roCNZmSZyDweazZPFQ8eq  0.9040
